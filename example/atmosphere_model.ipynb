# %%
from pyionoseis.source import EarthquakeSource
source = EarthquakeSource(r"event.toml")
print(source)
# Out:
# EarthquakeSource(time=2023-10-01T12:34:56Z, latitude=37.7749, longitude=-122.4194, depth=10.0)

# %%
from pyionoseis.model import Model3D
model = Model3D(r"event.toml")
print(model)
# Out:
# Model3D: name=example, radius=500.0 (km), height=500.0 (km), winds=False, grid_spacing=0.5 (deg), height_spacing=50.0 (km), source=None

# %%
model.assign_source(source)
print(model)
# Out:
# Model3D: name=example, radius=500.0 (km), height=500.0 (km), winds=False, grid_spacing=0.5 (deg), height_spacing=50.0 (km), source=latitude=37.7749, longitude=-122.4194

# %%
model.plot()

# %%
model.make_3Dgrid()
print(model)
# Out:
# Model3D: name=example, radius=500.0 (km), height=500.0 (km), winds=False, grid_spacing=0.5 (deg), height_spacing=50.0 (km), source=latitude=37.7749, longitude=-122.4194 lat_extent=(33.28334412504492, 41.78334412504492) lon_extent=(-126.91095587495508, -118.41095587495508)

# %%
# make plot grid code
model.plot_grid(show_gridlines=True)
